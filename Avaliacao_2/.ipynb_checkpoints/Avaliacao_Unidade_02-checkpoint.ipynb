# %% [markdown]
# Avaliação - Unidade 02
# ===

# %% [markdown]
# Identificação dos alunos (nome completo):
#
# - Este trabalho irá compor 40% da segunda unidade.
# - Grupo de até dois alunos.
# - Os alunos deverão enviar (apenas um por grupo) através do Sigaa, o notebook e os datasets gerados na avaliação em um arquivo compactado (.zip).
# - Todas as respostas devem ser realizadas através de código python e os resultados explicados em estilo markdown
# - As informações (datasets) necessárias para resolução dos problemas podem ser encontradas em http://dados.ufrn.br/group/ensino

# %% [markdown]
# \# 1. (1 ponto) Quantas e quais disciplinas com código IMD foram consolidadas em 2017.1?
# **Dica:**
# >```python
# df[df['A'].str.contains("hello")]
# ```

# %%
import pandas as pd

# %%
turmas_total = pd.read_csv('turmas-2017.1.csv', sep=";")

turmas_imd  = turmas_total[turmas_total['codigo'].str.contains("IMD")]

turmas_consolidadas = turmas_imd[turmas_imd["situacao_turma"].str.contains("CONSOLIDADA")]

print("Turmas consolidadas:",turmas_consolidadas.shape[0])
turmas_consolidadas.pivot_table(index="nome_ascii", values="situacao_turma", aggfunc='count')
# Out:
# Turmas consolidadas: 103
#                                                     situacao_turma
# nome_ascii
# ADMINISTRACAO DE SISTEMAS OPERACIONAIS PARA REDES                1
# ANALISE ESTATISTICA PARA BIG DATA                                1
# APRENDIZAGEM DE MAQUINA PARA BIG DATA                            1
# ARMAZENAMENTO DE BIG DATA                                        1
# AVALIACAO DA INTERACAO HUMANO-COMPUTADOR                         1
# CALCULO DIFERENCIAL E INTEGRAL I                                 3
# DESENVOLVIMENTO DE PROJETOS DE REDES DE COMPUTA...               1
# DESENVOLVIMENTO DE SISTEMAS WEB II                               1
# DESIGN DA INTERACAO HUMANO-COMPUTADOR                            1
# DESIGN DE SOFTWARE I                                             1
# EDUCACAO A DISTANCIA                                             1
# ESTRUTURA DE DADOS BASICAS I                                     4
# ESTRUTURAS DE DADOS BASICAS II                                   2
# FUNDAMENTOS DE JOGOS DIGITAIS                                    1
# FUNDAMENTOS DE SISTEMAS DE INFORMACAO                            1
# FUNDAMENTOS MATEMATICOS DA COMPUTACAO I                          3
# FUNDAMENTOS MATEMATICOS DA COMPUTACAO II                         2
# FUNDAMENTOS PEDAGOGICOS PARA A INFORMATICA EDUC...               1
# GESTAO DE INFRAESTRUTURA DE TI                                   1
# INTRODUCAO A ORGANIZACAO E ARQUITETURA DE COMPU...               2
# INTRODUCAO AS TECNICAS DE PROGRAMACAO                            5
# LINGUAGEM DE PROGRAMACAO I                                       5
# LINGUAGEM DE PROGRAMACAO II                                      2
# METODOLOGIAS DE PROJETOS EM SISTEMAS EMBARCADOS                  1
# MINERACAO DE DADOS                                               1
# PRATICAS DE LEITURA E ESCRITA EM PORTUGUES I                     5
# PRATICAS DE LEITURA E ESCRITA EM PORTUGUES II                    2
# PRATICAS DE LEITURA EM INGLES                                    5
# PRATICAS DE TECNICAS DE PROGRAMACAO                              4
# PRINCIPIOS DE LEGISLACAO APLICAVEIS A TECNOLOGI...               1
# PROBABILIDADE                                                    2
# PROCESSOS DE SOFTWARE                                            1
# PROGRAMACAO CIENTIFICA PARA BIG DATA                             1
# PROGRAMACAO COM BANCO DE DADOS                                   1
# PROGRAMACAO EM HARDWARE DE REDES                                 2
# PROJETO DE INOVACAO TECNOLOGICA                                  2
# PROJETO INTEGRADO I                                              1
# PROJETO INTEGRADOR DE REDES I                                    1
# REDES DE COMPUTADORES                                            1
# RESOLUCAO DE PROBLEMAS MATEMATICOS PARA TI                      10
# SISTEMA DE INFORMACAO DISTRIBUIDO                                1
# SISTEMAS COLABORATIVOS DE APOIO A APRENDIZAGEM                   1
# SISTEMAS DIGITAIS RECONFIGURAVEIS                                2
# SISTEMAS EMBARCADOS DE TEMPO REAL                                1
# TECNICAS DE PROTOTIPACAO E MONTAGEM DE CIRCUITO...               1
# TECNOLOGIA DA INFORMACAO E SOCIEDADE                             5
# TECNOLOGIAS DE COMUNICACAO DE DADOS                              1
# TEORIA DE CIRCUITOS ELETRICOS                                    1
# TOPICOS AVANCADOS EM COMPUTACAO MOVEL II                         1
# TOPICOS ESPECIAIS EM REDES DE COMPUTADORES B"                    1
# TOPICOS ESPECIAIS EM TECNOLOGIA DA INFORMACAO VI                 1
# TOPICOS ESPECIAIS EM TECNOLOGIA DA INFORMACAO XI                 1
# VETORES E GEOMETRIA ANALITICA                                    3

# %% [markdown]
# \# 2. (3 pontos) Realize um estudo envolvendo as propriedades de **assimétria** e **curtose** para as turmas IMD0033 (probabilidade) consolidadas em 2017.1. Utilize gráficos e explique os resultados. Reforce também os horários das disciplinas nos resultados.

# %%
turmas_prob = turmas_imd[turmas_imd["codigo"].str.contains("IMD0033")]


codigo_turma = list(turmas_prob['id_turma'])

# %%
alunos_total = pd.read_csv('matricula-componente-20171.csv', sep=";")

# %%
alunos_prob1 = alunos_total[alunos_total["id_turma"] == codigo_turma[0]]
alunos_prob1 = alunos_prob1.dropna()
alunos_prob2 = alunos_total[alunos_total["id_turma"] == codigo_turma[1]]
alunos_prob2 = alunos_prob2.dropna()

# %%
# We can test how skewed a distribution is using the skew function.
# A positive value means positive skew, 
# a negative value means negative skew, and close to zero means no skew.
from scipy.stats import skew

skewness_turma_a = skew(alunos_prob1['nota'].value_counts())
skewness_turma_b = skew(alunos_prob2['nota'].value_counts())

# %%
from scipy.stats import kurtosis

kurtosiness_turma_a = kurtosis(alunos_prob1['nota'].value_counts())
kurtosiness_turma_b = kurtosis(alunos_prob2['nota'].value_counts())

# %%
# seaborn is commonly imported as `sns`.
import matplotlib.pyplot as plt
import seaborn as sns

#to switch to seaborn defaults, simply call the set() function.
sns.set()

# The four preset contexts, in order of relative size, are paper, notebook, talk, and poster
sns.set_context("notebook")

# %%
fig, axes = plt.subplots(ncols=2, figsize=(12, 5))

sns.set_style("white")
sns.kdeplot(alunos_prob1["nota"], shade=True, ax=axes[0])
sns.kdeplot(alunos_prob2["nota"], shade=True, ax=axes[1])
axes[0].set_xlabel('Nota')
axes[1].set_xlabel("Nota")

sns.despine(left=True, bottom=True)
axes[0].set_title("Turma "+str(codigo_turma[0]))
axes[1].set_title("Turma "+str(codigo_turma[1]))

print("A simetria da turma", codigo_turma[0],"é", skewness_turma_a)
print("A simetria da turma", codigo_turma[1],"é", skewness_turma_b)
print("A curtose da turma", codigo_turma[0],"é", kurtosiness_turma_a)
print("A curtose da turma", codigo_turma[1],"é", kurtosiness_turma_b)

plt.show()
# Out:
# A simetria da turma 57597912 é 4.392894113344194
# A simetria da turma 57597913 é 3.9785262183599515
# A curtose da turma 57597912 é 21.38177433896744
# A curtose da turma 57597913 é 17.362042170356005

# %% [markdown]
# \# 3. (3 pontos) Utilize a biblioteca seaborn para traçar gráficos que descrevam as distribuições estatísticas (utilizar as funções **facetgrid** e **map**) de todas as turmas IMD0030 (Linguagem de Programação I) consolidas em 2017.1. Na análise, assuma como referência as médias finais e a situação dos alunos.

# %%
turmas_lp1 = turmas_imd[turmas_imd["codigo"].str.contains("IMD0030")]

codigo_lp1 = list(turmas_lp1['id_turma'].unique())

lista_alunos_lp1 = pd.DataFrame

lista_alunos_lp1 = alunos_total.loc[alunos_total["id_turma"].isin(codigo_lp1)].dropna()

lista_alunos_lp1 = lista_alunos_lp1.drop_duplicates(subset = "id_discente", keep="first").dropna()


# Condition on unique values of the "Survived" column.
g = sns.FacetGrid(lista_alunos_lp1, row="id_turma", hue="situacao", size=5, aspect=3, legend_out=False)
g.add_legend()
# For each subset of values, generate a kernel density plot of the "Age" columns.
g.map(sns.kdeplot, "media_final", shade=True)

sns.despine(left=True, bottom=True)

plt.show()
# Out:
# C:\Users\IMD\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:494: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X,a,b,gridsize)/(delta*nobs)
# C:\Users\IMD\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\IMD\Anaconda3\lib\site-packages\numpy\core\_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\IMD\Anaconda3\lib\site-packages\numpy\core\_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\IMD\Anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py:22: RuntimeWarning: invalid value encountered in minimum
#   return np.minimum(np.std(X, axis=0, ddof=1), IQR)

# %% [markdown]
# \# 4. (3 pontos) Utilize a biblioteca seaborn para traçar gráficos de histograma referente as médias finais de todas as turmas IMD0029 (Estrutura de dados I) consolidadas em 2017.1. Incremente nos gráficos linhas que descrevam a média e mediana da distribuição.

# %%
fig, ([ax1, ax2], [ax3, ax4]) = plt.subplots(figsize=(12,10), nrows=2, ncols=2)

# organize space among figures
fig.tight_layout()

y_title_margin = 1

turmas_edb1 = turmas_imd[turmas_imd["codigo"].str.contains("IMD0029")]

codigo_edb1 = list(turmas_edb1['id_turma'].unique())

print(codigo_edb1)

lista_alunos_edb1_a = pd.DataFrame
lista_alunos_edb1_a = alunos_total.loc[alunos_total["id_turma"] == codigo_edb1[0]].dropna()
lista_alunos_edb1_a = lista_alunos_edb1.drop_duplicates(subset = "id_discente", keep="first").dropna()

lista_alunos_edb1_b = pd.DataFrame
lista_alunos_edb1_b = alunos_total.loc[alunos_total["id_turma"] == codigo_edb1[1]].dropna()
lista_alunos_edb1_b = lista_alunos_edb1.drop_duplicates(subset = "id_discente", keep="first").dropna()

lista_alunos_edb1_c = pd.DataFrame
lista_alunos_edb1_c = alunos_total.loc[alunos_total["id_turma"] == codigo_edb1[2]].dropna()
lista_alunos_edb1_c = lista_alunos_edb1.drop_duplicates(subset = "id_discente", keep="first").dropna()

lista_alunos_edb1_d = pd.DataFrame
lista_alunos_edb1_d = alunos_total.loc[alunos_total["id_turma"] == codigo_edb1[3]].dropna()
lista_alunos_edb1_d = lista_alunos_edb1.drop_duplicates(subset = "id_discente", keep="first").dropna()

# Plot the mean in red
ax1.axvline(lista_alunos_edb1_a['media_final'].mean(), color="r")
ax2.axvline(lista_alunos_edb1_b['media_final'].mean(), color="r")
ax3.axvline(lista_alunos_edb1_c['media_final'].mean(), color="r")
ax4.axvline(lista_alunos_edb1_d['media_final'].mean(), color="r")

# Plot the median in green
ax1.axvline(lista_alunos_edb1_a['media_final'].median(), color="g")
ax2.axvline(lista_alunos_edb1_b['media_final'].median(), color="g")
ax3.axvline(lista_alunos_edb1_c['media_final'].median(), color="g")
ax4.axvline(lista_alunos_edb1_d['media_final'].median(), color="g")

sns.distplot(lista_alunos_edb1_a['media_final'], kde = False, ax=ax1,bins=20)
ax1.set_title("Turma " + str(codigo_edb1[0]))
ax1.set_xlabel("Media final")
sns.distplot(lista_alunos_edb1_b['media_final'], kde = False, ax=ax2,bins=20)
ax2.set_title("Turma " + str(codigo_edb1[1]))
ax2.set_xlabel("Media final")
sns.distplot(lista_alunos_edb1_c['media_final'], kde = False, ax=ax3,bins=20)
ax3.set_title("Turma " + str(codigo_edb1[2]))
ax3.set_xlabel("Media final")
sns.distplot(lista_alunos_edb1_d['media_final'], kde = False, ax=ax4,bins=20)
ax4.set_title("Turma " + str(codigo_edb1[3]))
ax4.set_xlabel("Media final")

print(lista_alunos_edb1_a['media_final'].mean())
print(lista_alunos_edb1_b['media_final'].mean())
print(lista_alunos_edb1_c['media_final'].mean())
print(lista_alunos_edb1_d['media_final'].mean())

# Plot the graph
lista_alunos_edb1_b.head()
# Out:
# [57597598, 57597708, 57597710, 57600131]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-fb66ffe8f641> in <module>()
#      14 lista_alunos_edb1_a = pd.DataFrame
#      15 lista_alunos_edb1_a = alunos_total.loc[alunos_total["id_turma"] == codigo_edb1[0]].dropna()
# ---> 16 lista_alunos_edb1_a = lista_alunos_edb1.drop_duplicates(subset = "id_discente", keep="first").dropna()
#      17
#      18 lista_alunos_edb1_b = pd.DataFrame
#
# NameError: name 'lista_alunos_edb1' is not defined
